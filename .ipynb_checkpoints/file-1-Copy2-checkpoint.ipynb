# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Dataset.csv',low_memory=False)
df.head(10)
# Out:
#   policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 0   ID00001       0.515874        0.05             0.644231           C1
# 1   ID00002       0.672619        0.02             0.375000           C2
# 2   ID00003       0.841110        0.02             0.384615           C3
# 3   ID00004       0.900277        0.11             0.432692           C4
# 4   ID00005       0.596403        0.11             0.634615           C5
# 5   ID00006       1.018709        0.07             0.519231           C6
# 6   ID00007       0.097992        0.16             0.403846           C7
# 7   ID00008       0.509085        0.14             0.423077           C8
# 8   ID00009       0.282394        0.07             0.298077           C7
# 9   ID00010       0.566255        0.04             0.442308           C9
#
#   population_density  make  is_claim segment model  ...  \
# 0               4990     1         0       A    M1  ...
# 1             27003"     1         0       A    M1  ...
# 2               4076     1         0       A    M1  ...
# 3             21622"     1         0      C1    M2  ...
# 4              34738     2         0       A    M3  ...
# 5             13051"     3         0      C2    M4  ...
# 6               6112     4         0      B2    M5  ...
# 7              8794"     1         0      B2    M6  ...
# 8               6112     3         0      C2    M4  ...
# 9              17804     1         0      B2    M7  ...
#
#   is_rear_window_defogger is_brake_assist is_power_door_locks  \
# 0                      No              No                  No
# 1                      No              No                  No
# 2                      No              No                  No
# 3                     Yes             Yes                 Yes
# 4                      No              No                 Yes
# 5                     Yes             Yes                 Yes
# 6                      No              No                 Yes
# 7                      No             Yes                 Yes
# 8                     Yes             Yes                 Yes
# 9                     Yes             Yes                 Yes
#
#   is_central_locking  is_power_steering is_driver_seat_height_adjustable  \
# 0                 No                Yes                               No
# 1                 No                Yes                               No
# 2                 No                Yes                               No
# 3                Yes                Yes                              Yes
# 4                Yes                Yes                               No
# 5                Yes                Yes                              Yes
# 6                Yes                Yes                               No
# 7                Yes                Yes                              Yes
# 8                Yes                Yes                              Yes
# 9                Yes                Yes                              Yes
#
#   is_day_night_rear_view_mirror is_ecw is_speed_alert ncap_rating
# 0                            No     No            Yes           0
# 1                            No     No            Yes           0
# 2                            No     No            Yes           0
# 3                           Yes    Yes            Yes           2
# 4                           Yes    Yes            Yes           2
# 5                            No    Yes            Yes           3
# 6                            No    Yes            Yes           5
# 7                           Yes    Yes            Yes           2
# 8                            No    Yes            Yes           3
# 9                           Yes    Yes            Yes           0
#
# [10 rows x 44 columns]

# %%
df['is_claim'].value_counts()
# Out:
# is_claim
# 0    28171
# 1     1929
# Name: count, dtype: int64

# %%
from sklearn.utils import resample
# Separate the majority and minority classes
majority_class = df[df['is_claim'] == 0]
minority_class = df[df['is_claim'] == 1]

# Undersample the majority class
undersampled_majority = resample(
    majority_class,
    replace=False,  # Set to False for undersampling
    n_samples=len(minority_class) * 3,  # Desired number of records in the majority class
    random_state=42  # Set a random seed for reproducibility
)

# Combine the undersampled majority class with the minority class
df = pd.concat([undersampled_majority, minority_class])

# %%
df['is_claim'].value_counts()
# Out:
# is_claim
# 0    3858
# 1    1929
# Name: count, dtype: int64

# %%
df['population_density'].value_counts()
# Out:
# population_density
# 8794      1399
# 27003      745
# 4076       628
# 34738      627
# 7788       386
# 5410       325
# 73430      279
# 17804      267
# 6112       213
# 34791      147
# 4990       135
# 6108       129
# 13051      106
# 27742       90
# 21622       81
# 290         69
# 3264        43
# 65567       35
# 16206       29
# 35036       26
# 16733       20
# 20905        7
# 27003_       1
# Name: count, dtype: int64

# %%
# removing impure values

l= ['27003_','27003"','8794"','34738_','73430_','16206_','4076_',
    '4076"','13051"','21622"','5410"','6108"']
for val in l:
    condition = (df['population_density'] == val );
    df = df[~condition]
df['population_density'].value_counts()
# Out:
# population_density
# 8794     1399
# 27003     745
# 4076      628
# 34738     627
# 7788      386
# 5410      325
# 73430     279
# 17804     267
# 6112      213
# 34791     147
# 4990      135
# 6108      129
# 13051     106
# 27742      90
# 21622      81
# 290        69
# 3264       43
# 65567      35
# 16206      29
# 35036      26
# 16733      20
# 20905       7
# Name: count, dtype: int64

# %%
df['max_torque'].value_counts()
# Out:
# max_torque
# 113Nm@4400rpm     1843
# 60Nm@3500rpm      1436
# 250Nm@2750rpm     1348
# 82.1Nm@3400rpm     400
# 91Nm@4250rpm       224
# 200Nm@1750rpm      201
# 200Nm@3000rpm      180
# 85Nm@3000rpm       128
# 170Nm@4000rpm       26
# Name: count, dtype: int64

# %%
df['area_cluster']
# Out:
# 6311      C8
# 972       C2
# 22940     C2
# 7625      C1
# 8763      C8
#         ...
# 29959     C7
# 29971     C2
# 30023    C12
# 30048    C22
# 30074     C3
# Name: area_cluster, Length: 5786, dtype: object

# %%
df.describe()
# Out:
#        policy_tenure   age_of_car  age_of_policyholder         make  \
# count    5786.000000  5786.000000          5786.000000  5786.000000
# mean        0.656098     0.068094             0.471313     1.750432
# std         0.408655     0.055786             0.123419     1.133113
# min         0.002748     0.000000             0.288462     1.000000
# 25%         0.264767     0.020000             0.375000     1.000000
# 50%         0.660747     0.060000             0.451923     1.000000
# 75%         1.058981     0.110000             0.548077     3.000000
# max         1.335945     0.450000             0.951923     5.000000
#
#           is_claim      airbags  displacement     cylinder     gear_box  \
# count  5786.000000  5786.000000   5786.000000  5786.000000  5786.000000
# mean      0.333218     3.122019   1164.792084     3.639475     5.237470
# std       0.471405     1.827659    263.625290     0.480194     0.425569
# min       0.000000     1.000000    796.000000     3.000000     5.000000
# 25%       0.000000     2.000000    998.000000     3.000000     5.000000
# 50%       0.000000     2.000000   1197.000000     4.000000     5.000000
# 75%       1.000000     6.000000   1493.000000     4.000000     5.000000
# max       1.000000     6.000000   1498.000000     4.000000     6.000000
#
#        turning_radius       height  ncap_rating
# count     5786.000000  5786.000000  5786.000000
# mean         4.851443  1553.048220     1.762530
# std          0.225667    79.615645     1.389161
# min          4.500000  1475.000000     0.000000
# 25%          4.600000  1490.000000     0.000000
# 50%          4.800000  1530.000000     2.000000
# 75%          5.000000  1635.000000     3.000000
# max          5.200000  1825.000000     5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5786 entries, 6311 to 30074
# Data columns (total 44 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   policy_id                         5786 non-null   object
#  1   policy_tenure                     5786 non-null   float64
#  2   age_of_car                        5786 non-null   float64
#  3   age_of_policyholder               5786 non-null   float64
#  4   area_cluster                      5786 non-null   object
#  5   population_density                5786 non-null   object
#  6   make                              5786 non-null   int64
#  7   is_claim                          5786 non-null   int64
#  8   segment                           5786 non-null   object
#  9   model                             5786 non-null   object
#  10  fuel_type                         5786 non-null   object
#  11  max_torque                        5786 non-null   object
#  12  max_power                         5786 non-null   object
#  13  engine_type                       5786 non-null   object
#  14  airbags                           5786 non-null   int64
#  15  is_esc                            5786 non-null   object
#  16  is_adjustable_steering            5786 non-null   object
#  17  is_tpms                           5786 non-null   object
#  18  is_parking_sensors                5786 non-null   object
#  19  is_parking_camera                 5786 non-null   object
#  20  rear_brakes_type                  5786 non-null   object
#  21  displacement                      5786 non-null   int64
#  22  cylinder                          5786 non-null   int64
#  23  transmission_type                 5786 non-null   object
#  24  gear_box                          5786 non-null   int64
#  25  steering_type                     5786 non-null   object
#  26  turning_radius                    5786 non-null   float64
#  27  Length                            5786 non-null   object
#  28  width                             5786 non-null   object
#  29  height                            5786 non-null   int64
#  30  Gross_weight                      5786 non-null   object
#  31  is_front_fog_lights               5786 non-null   object
#  32  is_rear_window_wiper              5786 non-null   object
#  33  is_rear_window_washer             5786 non-null   object
#  34  is_rear_window_defogger           5786 non-null   object
#  35  is_brake_assist                   5786 non-null   object
#  36  is_power_door_locks               5786 non-null   object
#  37  is_central_locking                5786 non-null   object
#  38  is_power_steering                 5786 non-null   object
#  39  is_driver_seat_height_adjustable  5786 non-null   object
#  40  is_day_night_rear_view_mirror     5786 non-null   object
#  41  is_ecw                            5786 non-null   object
#  42  is_speed_alert                    5786 non-null   object
#  43  ncap_rating                       5786 non-null   int64
# dtypes: float64(4), int64(8), object(32)
# memory usage: 2.0+ MB

# %%
df.columns
# Out:
# Index(['policy_id', 'policy_tenure', 'age_of_car', 'age_of_policyholder',
#        'area_cluster', 'population_density', 'make', 'is_claim', 'segment',
#        'model', 'fuel_type', 'max_torque', 'max_power', 'engine_type',
#        'airbags', 'is_esc', 'is_adjustable_steering', 'is_tpms',
#        'is_parking_sensors', 'is_parking_camera', 'rear_brakes_type',
#        'displacement', 'cylinder', 'transmission_type', 'gear_box',
#        'steering_type', 'turning_radius', 'Length', 'width', 'height',
#        'Gross_weight', 'is_front_fog_lights', 'is_rear_window_wiper',
#        'is_rear_window_washer', 'is_rear_window_defogger', 'is_brake_assist',
#        'is_power_door_locks', 'is_central_locking', 'is_power_steering',
#        'is_driver_seat_height_adjustable', 'is_day_night_rear_view_mirror',
#        'is_ecw', 'is_speed_alert', 'ncap_rating'],
#       dtype='object')

# %%
df['max_torque'].value_counts()
# Out:
# max_torque
# 113Nm@4400rpm     1843
# 60Nm@3500rpm      1436
# 250Nm@2750rpm     1348
# 82.1Nm@3400rpm     400
# 91Nm@4250rpm       224
# 200Nm@1750rpm      201
# 200Nm@3000rpm      180
# 85Nm@3000rpm       128
# 170Nm@4000rpm       26
# Name: count, dtype: int64

# %%
import re
df['torque'] = df['max_torque'].apply(lambda x: re.findall(r'\d+\.?\d*(?=Nm)', x)[0])
df['rpm'] = df['max_torque'].apply(lambda x: re.findall(r'\d+\.?\d*(?=rpm)', x)[0])

# Convert the columns to numeric data type
df['torque'] = pd.to_numeric(df['torque'])
df['rpm'] = pd.to_numeric(df['rpm'])

# Calculate torque to RPM ratio 
df['torque to rpm ratio'] = df['torque'] / df['rpm']
df['torque to rpm ratio']
# Out:
# 6311     0.025682
# 972      0.025682
# 22940    0.025682
# 7625     0.025682
# 8763     0.025682
#            ...
# 29959    0.017143
# 29971    0.090909
# 30023    0.025682
# 30048    0.025682
# 30074    0.017143
# Name: torque to rpm ratio, Length: 5786, dtype: float64

# %%
df['max_power'].value_counts()
# Out:
# max_power
# 88.50bhp@6000rpm     1843
# 40.36bhp@6000rpm     1436
# 113.45bhp@4000rpm    1348
# 55.92bhp@5300rpm      400
# 67.06bhp@5500rpm      224
# 97.89bhp@3600rpm      201
# 88.77bhp@4000rpm      180
# 61.68bhp@6000rpm      128
# 118.36bhp@5500rpm      26
# Name: count, dtype: int64

# %%
import re
df['power'] = df['max_power'].apply(lambda x: re.findall(r'\d+\.?\d*(?=bhp)', x)[0])
df['rpm1'] = df['max_power'].apply(lambda x: re.findall(r'\d+\.?\d*(?=rpm)', x)[0])

# Convert the columns to numeric data type
df['power'] = pd.to_numeric(df['power'])
df['rpm1'] = pd.to_numeric(df['rpm1'])

# Calculate torque to RPM ratio 
df['power to rpm ratio'] = df['power'] / df['rpm1']
df['power to rpm ratio']
# Out:
# 6311     0.014750
# 972      0.014750
# 22940    0.014750
# 7625     0.014750
# 8763     0.014750
#            ...
# 29959    0.006727
# 29971    0.028363
# 30023    0.014750
# 30048    0.014750
# 30074    0.006727
# Name: power to rpm ratio, Length: 5786, dtype: float64

# %%
df
# Out:
#       policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 6311    ID06312       0.427671        0.10             0.576923           C8
# 972     ID00973       0.011192        0.12             0.548077           C2
# 22940   ID22941       0.579031        0.00             0.490385           C2
# 7625    ID07626       0.099053        0.01             0.461538           C1
# 8763    ID08764       1.026959        0.14             0.682692           C8
# ...         ...            ...         ...                  ...          ...
# 29959   ID29960       0.522648        0.00             0.432692           C7
# 29971   ID29972       0.998589        0.08             0.528846           C2
# 30023   ID30024       0.795711        0.11             0.336538          C12
# 30048   ID30049       1.173214        0.04             0.346154          C22
# 30074   ID30075       0.946167        0.02             0.394231           C3
#
#       population_density  make  is_claim segment model  ...  \
# 6311                8794     1         0      B2    M6  ...
# 972                27003     1         0      B2    M6  ...
# 22940              27003     1         0      B2    M6  ...
# 7625                4990     1         0      B2    M6  ...
# 8763                8794     1         0      B2    M6  ...
# ...                  ...   ...       ...     ...   ...  ...
# 29959               6112     1         1       A    M1  ...
# 29971              27003     3         1      C2    M4  ...
# 30023              34791     1         1      B2    M6  ...
# 30048              16733     1         1      B2    M6  ...
# 30074               4076     1         1       A    M1  ...
#
#       is_day_night_rear_view_mirror is_ecw is_speed_alert ncap_rating  torque  \
# 6311                            Yes    Yes            Yes           2   113.0
# 972                             Yes    Yes            Yes           2   113.0
# 22940                           Yes    Yes            Yes           2   113.0
# 7625                            Yes    Yes            Yes           2   113.0
# 8763                            Yes    Yes            Yes           2   113.0
# ...                             ...    ...            ...         ...     ...
# 29959                            No     No            Yes           0    60.0
# 29971                            No    Yes            Yes           3   250.0
# 30023                           Yes    Yes            Yes           2   113.0
# 30048                           Yes    Yes            Yes           2   113.0
# 30074                            No     No            Yes           0    60.0
#
#         rpm torque to rpm ratio   power  rpm1 power to rpm ratio
# 6311   4400            0.025682   88.50  6000           0.014750
# 972    4400            0.025682   88.50  6000           0.014750
# 22940  4400            0.025682   88.50  6000           0.014750
# 7625   4400            0.025682   88.50  6000           0.014750
# 8763   4400            0.025682   88.50  6000           0.014750
# ...     ...                 ...     ...   ...                ...
# 29959  3500            0.017143   40.36  6000           0.006727
# 29971  2750            0.090909  113.45  4000           0.028363
# 30023  4400            0.025682   88.50  6000           0.014750
# 30048  4400            0.025682   88.50  6000           0.014750
# 30074  3500            0.017143   40.36  6000           0.006727
#
# [5786 rows x 50 columns]

# %%
df.columns
# Out:
# Index(['policy_id', 'policy_tenure', 'age_of_car', 'age_of_policyholder',
#        'area_cluster', 'population_density', 'make', 'is_claim', 'segment',
#        'model', 'fuel_type', 'max_torque', 'max_power', 'engine_type',
#        'airbags', 'is_esc', 'is_adjustable_steering', 'is_tpms',
#        'is_parking_sensors', 'is_parking_camera', 'rear_brakes_type',
#        'displacement', 'cylinder', 'transmission_type', 'gear_box',
#        'steering_type', 'turning_radius', 'Length', 'width', 'height',
#        'Gross_weight', 'is_front_fog_lights', 'is_rear_window_wiper',
#        'is_rear_window_washer', 'is_rear_window_defogger', 'is_brake_assist',
#        'is_power_door_locks', 'is_central_locking', 'is_power_steering',
#        'is_driver_seat_height_adjustable', 'is_day_night_rear_view_mirror',
#        'is_ecw', 'is_speed_alert', 'ncap_rating', 'torque', 'rpm',
#        'torque to rpm ratio', 'power', 'rpm1', 'power to rpm ratio'],
#       dtype='object')

# %%
df = pd.DataFrame(df)
def remove_units(value):
    return value.replace('(mm)','').replace("KG",'')

df['Length'] = df['Length'].apply(remove_units)
df['width'] = df['width'].apply(remove_units)
df['Gross_weight'] = df['Gross_weight'].apply(remove_units)

# %% [markdown]
# ## one hot encoding

# %%
data = pd.DataFrame(df['fuel_type'])
df= pd.get_dummies(df,columns=['fuel_type'],prefix='fuel_type',dtype=int)
data = pd.DataFrame(df['model'])
df= pd.get_dummies(df,columns=['model'],prefix='model',dtype=int)
data = pd.DataFrame(df['rear_brakes_type'])
df= pd.get_dummies(df,columns=['rear_brakes_type'],prefix='rear_brakes_type',dtype=int)
data = pd.DataFrame(df['transmission_type'])
df= pd.get_dummies(df,columns=['transmission_type'],prefix='transmission_type',dtype=int)
data = pd.DataFrame(df['steering_type'])
df= pd.get_dummies(df,columns=['steering_type'],prefix='steering_type',dtype=int)
data = pd.DataFrame(df['segment'])
df= pd.get_dummies(df,columns=['segment'],prefix='segment',dtype=int)
data = pd.DataFrame(df['engine_type'])
df= pd.get_dummies(df,columns=['engine_type'],prefix='engine_type',dtype=int)
data = pd.DataFrame(df['area_cluster'])
df= pd.get_dummies(df,columns=['area_cluster'],prefix='area_cluster',dtype=int)
df
# Out:
#       policy_id  policy_tenure  age_of_car  age_of_policyholder  \
# 6311    ID06312       0.427671        0.10             0.576923
# 972     ID00973       0.011192        0.12             0.548077
# 22940   ID22941       0.579031        0.00             0.490385
# 7625    ID07626       0.099053        0.01             0.461538
# 8763    ID08764       1.026959        0.14             0.682692
# ...         ...            ...         ...                  ...
# 29959   ID29960       0.522648        0.00             0.432692
# 29971   ID29972       0.998589        0.08             0.528846
# 30023   ID30024       0.795711        0.11             0.336538
# 30048   ID30049       1.173214        0.04             0.346154
# 30074   ID30075       0.946167        0.02             0.394231
#
#       population_density  make  is_claim     max_torque          max_power  \
# 6311                8794     1         0  113Nm@4400rpm   88.50bhp@6000rpm
# 972                27003     1         0  113Nm@4400rpm   88.50bhp@6000rpm
# 22940              27003     1         0  113Nm@4400rpm   88.50bhp@6000rpm
# 7625                4990     1         0  113Nm@4400rpm   88.50bhp@6000rpm
# 8763                8794     1         0  113Nm@4400rpm   88.50bhp@6000rpm
# ...                  ...   ...       ...            ...                ...
# 29959               6112     1         1   60Nm@3500rpm   40.36bhp@6000rpm
# 29971              27003     3         1  250Nm@2750rpm  113.45bhp@4000rpm
# 30023              34791     1         1  113Nm@4400rpm   88.50bhp@6000rpm
# 30048              16733     1         1  113Nm@4400rpm   88.50bhp@6000rpm
# 30074               4076     1         1   60Nm@3500rpm   40.36bhp@6000rpm
#
#        airbags  ... area_cluster_C20 area_cluster_C21 area_cluster_C22  \
# 6311         2  ...                0                0                0
# 972          2  ...                0                0                0
# 22940        2  ...                0                0                0
# 7625         2  ...                0                0                0
# 8763         2  ...                0                0                0
# ...        ...  ...              ...              ...              ...
# 29959        2  ...                0                0                0
# 29971        6  ...                0                0                0
# 30023        2  ...                0                0                0
# 30048        2  ...                0                0                1
# 30074        2  ...                0                0                0
#
#       area_cluster_C3 area_cluster_C4  area_cluster_C5  area_cluster_C6  \
# 6311                0               0                0                0
# 972                 0               0                0                0
# 22940               0               0                0                0
# 7625                0               0                0                0
# 8763                0               0                0                0
# ...               ...             ...              ...              ...
# 29959               0               0                0                0
# 29971               0               0                0                0
# 30023               0               0                0                0
# 30048               0               0                0                0
# 30074               1               0                0                0
#
#        area_cluster_C7  area_cluster_C8 area_cluster_C9
# 6311                 0                1               0
# 972                  0                0               0
# 22940                0                0               0
# 7625                 0                0               0
# 8763                 0                1               0
# ...                ...              ...             ...
# 29959                1                0               0
# 29971                0                0               0
# 30023                0                0               0
# 30048                0                0               0
# 30074                0                0               0
#
# [5786 rows x 102 columns]

# %%
df.columns
# Out:
# Index(['policy_id', 'policy_tenure', 'age_of_car', 'age_of_policyholder',
#        'population_density', 'make', 'is_claim', 'max_torque', 'max_power',
#        'airbags',
#        ...
#        'area_cluster_C20', 'area_cluster_C21', 'area_cluster_C22',
#        'area_cluster_C3', 'area_cluster_C4', 'area_cluster_C5',
#        'area_cluster_C6', 'area_cluster_C7', 'area_cluster_C8',
#        'area_cluster_C9'],
#       dtype='object', length=102)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5786 entries, 6311 to 30074
# Columns: 102 entries, policy_id to area_cluster_C9
# dtypes: float64(8), int64(70), object(24)
# memory usage: 4.5+ MB

# %%
df.drop(['policy_id','max_torque','max_power'],inplace=True,axis=1)
df
# Out:
#        policy_tenure  age_of_car  age_of_policyholder population_density  \
# 6311        0.427671        0.10             0.576923               8794
# 972         0.011192        0.12             0.548077              27003
# 22940       0.579031        0.00             0.490385              27003
# 7625        0.099053        0.01             0.461538               4990
# 8763        1.026959        0.14             0.682692               8794
# ...              ...         ...                  ...                ...
# 29959       0.522648        0.00             0.432692               6112
# 29971       0.998589        0.08             0.528846              27003
# 30023       0.795711        0.11             0.336538              34791
# 30048       1.173214        0.04             0.346154              16733
# 30074       0.946167        0.02             0.394231               4076
#
#        make  is_claim  airbags is_esc is_adjustable_steering is_tpms  ...  \
# 6311      1         0        2     No                    Yes      No  ...
# 972       1         0        2     No                    Yes      No  ...
# 22940     1         0        2     No                    Yes      No  ...
# 7625      1         0        2     No                    Yes      No  ...
# 8763      1         0        2     No                    Yes      No  ...
# ...     ...       ...      ...    ...                    ...     ...  ...
# 29959     1         1        2     No                     No      No  ...
# 29971     3         1        6    Yes                    Yes     Yes  ...
# 30023     1         1        2     No                    Yes      No  ...
# 30048     1         1        2     No                    Yes      No  ...
# 30074     1         1        2     No                     No      No  ...
#
#       area_cluster_C20 area_cluster_C21  area_cluster_C22  area_cluster_C3  \
# 6311                 0                0                 0                0
# 972                  0                0                 0                0
# 22940                0                0                 0                0
# 7625                 0                0                 0                0
# 8763                 0                0                 0                0
# ...                ...              ...               ...              ...
# 29959                0                0                 0                0
# 29971                0                0                 0                0
# 30023                0                0                 0                0
# 30048                0                0                 1                0
# 30074                0                0                 0                1
#
#        area_cluster_C4  area_cluster_C5 area_cluster_C6 area_cluster_C7  \
# 6311                 0                0               0               0
# 972                  0                0               0               0
# 22940                0                0               0               0
# 7625                 0                0               0               0
# 8763                 0                0               0               0
# ...                ...              ...             ...             ...
# 29959                0                0               0               1
# 29971                0                0               0               0
# 30023                0                0               0               0
# 30048                0                0               0               0
# 30074                0                0               0               0
#
#        area_cluster_C8 area_cluster_C9
# 6311                 1               0
# 972                  0               0
# 22940                0               0
# 7625                 0               0
# 8763                 1               0
# ...                ...             ...
# 29959                0               0
# 29971                0               0
# 30023                0               0
# 30048                0               0
# 30074                0               0
#
# [5786 rows x 99 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()


df['is_esc']=encoder.fit_transform(df['is_esc'])
df['is_adjustable_steering']=encoder.fit_transform(df['is_adjustable_steering'])
df['is_tpms']=encoder.fit_transform(df['is_tpms'])
df['is_parking_sensors']=encoder.fit_transform(df['is_parking_sensors'])
df['is_parking_camera']=encoder.fit_transform(df['is_parking_camera'])
df['is_front_fog_lights']=encoder.fit_transform(df['is_front_fog_lights'])
df['is_rear_window_washer']=encoder.fit_transform(df['is_rear_window_washer'])
df['is_rear_window_defogger']=encoder.fit_transform(df['is_rear_window_defogger'])
df['is_brake_assist']=encoder.fit_transform(df['is_brake_assist'])
df['is_power_door_locks']=encoder.fit_transform(df['is_power_door_locks'])
df['is_central_locking']=encoder.fit_transform(df['is_central_locking'])
df['is_power_steering']=encoder.fit_transform(df['is_power_steering'])
df['is_driver_seat_height_adjustable']=encoder.fit_transform(df['is_driver_seat_height_adjustable'])
df['is_day_night_rear_view_mirror']=encoder.fit_transform(df['is_day_night_rear_view_mirror'])
df['is_ecw']=encoder.fit_transform(df['is_ecw'])
df['is_speed_alert']=encoder.fit_transform(df['is_speed_alert'])
df['Length']=encoder.fit_transform(df['Length'])
df['width']=encoder.fit_transform(df['width'])
df['Gross_weight']=encoder.fit_transform(df['Gross_weight'])
df['is_rear_window_wiper']=encoder.fit_transform(df['is_rear_window_wiper'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5786 entries, 6311 to 30074
# Data columns (total 99 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   policy_tenure                          5786 non-null   float64
#  1   age_of_car                             5786 non-null   float64
#  2   age_of_policyholder                    5786 non-null   float64
#  3   population_density                     5786 non-null   object
#  4   make                                   5786 non-null   int64
#  5   is_claim                               5786 non-null   int64
#  6   airbags                                5786 non-null   int64
#  7   is_esc                                 5786 non-null   int64
#  8   is_adjustable_steering                 5786 non-null   int64
#  9   is_tpms                                5786 non-null   int64
#  10  is_parking_sensors                     5786 non-null   int64
#  11  is_parking_camera                      5786 non-null   int64
#  12  displacement                           5786 non-null   int64
#  13  cylinder                               5786 non-null   int64
#  14  gear_box                               5786 non-null   int64
#  15  turning_radius                         5786 non-null   float64
#  16  Length                                 5786 non-null   int64
#  17  width                                  5786 non-null   int64
#  18  height                                 5786 non-null   int64
#  19  Gross_weight                           5786 non-null   int64
#  20  is_front_fog_lights                    5786 non-null   int64
#  21  is_rear_window_wiper                   5786 non-null   int64
#  22  is_rear_window_washer                  5786 non-null   int64
#  23  is_rear_window_defogger                5786 non-null   int64
#  24  is_brake_assist                        5786 non-null   int64
#  25  is_power_door_locks                    5786 non-null   int64
#  26  is_central_locking                     5786 non-null   int64
#  27  is_power_steering                      5786 non-null   int64
#  28  is_driver_seat_height_adjustable       5786 non-null   int64
#  29  is_day_night_rear_view_mirror          5786 non-null   int64
#  30  is_ecw                                 5786 non-null   int64
#  31  is_speed_alert                         5786 non-null   int64
#  32  ncap_rating                            5786 non-null   int64
#  33  torque                                 5786 non-null   float64
#  34  rpm                                    5786 non-null   int64
#  35  torque to rpm ratio                    5786 non-null   float64
#  36  power                                  5786 non-null   float64
#  37  rpm1                                   5786 non-null   int64
#  38  power to rpm ratio                     5786 non-null   float64
#  39  fuel_type_CNG                          5786 non-null   int64
#  40  fuel_type_Diesel                       5786 non-null   int64
#  41  fuel_type_Petrol                       5786 non-null   int64
#  42  model_M1                               5786 non-null   int64
#  43  model_M10                              5786 non-null   int64
#  44  model_M11                              5786 non-null   int64
#  45  model_M2                               5786 non-null   int64
#  46  model_M3                               5786 non-null   int64
#  47  model_M4                               5786 non-null   int64
#  48  model_M5                               5786 non-null   int64
#  49  model_M6                               5786 non-null   int64
#  50  model_M7                               5786 non-null   int64
#  51  model_M8                               5786 non-null   int64
#  52  model_M9                               5786 non-null   int64
#  53  rear_brakes_type_Disc                  5786 non-null   int64
#  54  rear_brakes_type_Drum                  5786 non-null   int64
#  55  transmission_type_Automatic            5786 non-null   int64
#  56  transmission_type_Manual               5786 non-null   int64
#  57  steering_type_Electric                 5786 non-null   int64
#  58  steering_type_Manual                   5786 non-null   int64
#  59  steering_type_Power                    5786 non-null   int64
#  60  segment_A                              5786 non-null   int64
#  61  segment_B1                             5786 non-null   int64
#  62  segment_B2                             5786 non-null   int64
#  63  segment_C1                             5786 non-null   int64
#  64  segment_C2                             5786 non-null   int64
#  65  segment_Utility                        5786 non-null   int64
#  66  engine_type_1.0 SCe                    5786 non-null   int64
#  67  engine_type_1.2 L K Series Engine      5786 non-null   int64
#  68  engine_type_1.2 L K12N Dualjet         5786 non-null   int64
#  69  engine_type_1.5 L U2 CRDi              5786 non-null   int64
#  70  engine_type_1.5 Turbocharged Revotorq  5786 non-null   int64
#  71  engine_type_1.5 Turbocharged Revotron  5786 non-null   int64
#  72  engine_type_F8D Petrol Engine          5786 non-null   int64
#  73  engine_type_G12B                       5786 non-null   int64
#  74  engine_type_K Series Dual jet          5786 non-null   int64
#  75  engine_type_K10C                       5786 non-null   int64
#  76  engine_type_i-DTEC                     5786 non-null   int64
#  77  area_cluster_C1                        5786 non-null   int64
#  78  area_cluster_C10                       5786 non-null   int64
#  79  area_cluster_C11                       5786 non-null   int64
#  80  area_cluster_C12                       5786 non-null   int64
#  81  area_cluster_C13                       5786 non-null   int64
#  82  area_cluster_C14                       5786 non-null   int64
#  83  area_cluster_C15                       5786 non-null   int64
#  84  area_cluster_C16                       5786 non-null   int64
#  85  area_cluster_C17                       5786 non-null   int64
#  86  area_cluster_C18                       5786 non-null   int64
#  87  area_cluster_C19                       5786 non-null   int64
#  88  area_cluster_C2                        5786 non-null   int64
#  89  area_cluster_C20                       5786 non-null   int64
#  90  area_cluster_C21                       5786 non-null   int64
#  91  area_cluster_C22                       5786 non-null   int64
#  92  area_cluster_C3                        5786 non-null   int64
#  93  area_cluster_C4                        5786 non-null   int64
#  94  area_cluster_C5                        5786 non-null   int64
#  95  area_cluster_C6                        5786 non-null   int64
#  96  area_cluster_C7                        5786 non-null   int64
#  97  area_cluster_C8                        5786 non-null   int64
#  98  area_cluster_C9                        5786 non-null   int64
# dtypes: float64(8), int64(90), object(1)
# memory usage: 4.4+ MB

# %%
df['Length'].value_counts()
# Out:
# Length
# 0    1436
# 4    1424
# 8    1348
# 5     487
# 1     400
# 7     313
# 3     224
# 2     128
# 6      26
# Name: count, dtype: int64

# %%
df.corr()
# Out:
#                      policy_tenure  age_of_car  age_of_policyholder  \
# policy_tenure             1.000000    0.167382             0.151350
# age_of_car                0.167382    1.000000            -0.026895
# age_of_policyholder       0.151350   -0.026895             1.000000
# population_density       -0.092580   -0.070770             0.018235
# make                      0.117186    0.190297            -0.014334
# ...                            ...         ...                  ...
# area_cluster_C5          -0.073060   -0.064938             0.022337
# area_cluster_C6          -0.002231   -0.017511            -0.020159
# area_cluster_C7          -0.043203   -0.025076            -0.070694
# area_cluster_C8           0.184921    0.189789             0.040219
# area_cluster_C9          -0.078068   -0.015817             0.021410
#
#                      population_density      make  is_claim   airbags  \
# policy_tenure                 -0.092580  0.117186  0.140640  0.121549
# age_of_car                    -0.070770  0.190297 -0.069575  0.216567
# age_of_policyholder            0.018235 -0.014334  0.037825  0.005050
# population_density             1.000000 -0.064446 -0.015312 -0.074476
# make                          -0.064446  1.000000  0.003614  0.493488
# ...                                 ...       ...       ...       ...
# area_cluster_C5                0.342090 -0.055709 -0.004633 -0.049442
# area_cluster_C6               -0.040435  0.002792 -0.011814 -0.009121
# area_cluster_C7               -0.137762 -0.009593 -0.027213 -0.019582
# area_cluster_C8               -0.308732  0.101943  0.022118  0.133917
# area_cluster_C9               -0.003533 -0.011172 -0.027909 -0.013784
#
#                        is_esc  is_adjustable_steering   is_tpms  ...  \
# policy_tenure        0.123202                0.213590  0.106461  ...
# age_of_car           0.230468                0.394027  0.208524  ...
# age_of_policyholder -0.002672                0.021964  0.014514  ...
# population_density  -0.066545               -0.098360 -0.077934  ...
# make                 0.471191                0.426663  0.607821  ...
# ...                       ...                     ...       ...  ...
# area_cluster_C5     -0.046047               -0.104193 -0.052712  ...
# area_cluster_C6     -0.016297               -0.027681 -0.008218  ...
# area_cluster_C7     -0.027798               -0.036817 -0.010040  ...
# area_cluster_C8      0.133958                0.245268  0.140430  ...
# area_cluster_C9     -0.012006               -0.038700 -0.023784  ...
#
#                      area_cluster_C20  area_cluster_C21  area_cluster_C22  \
# policy_tenure               -0.034675         -0.003539          0.000526
# age_of_car                   0.000298         -0.001733          0.000957
# age_of_policyholder         -0.024838         -0.006227         -0.008565
# population_density           0.005797         -0.075489         -0.004661
# make                        -0.014275         -0.012910         -0.010419
# ...                               ...               ...               ...
# area_cluster_C5             -0.012133         -0.030166         -0.020532
# area_cluster_C6             -0.004754         -0.011821         -0.008046
# area_cluster_C7             -0.006804         -0.016916         -0.011514
# area_cluster_C8             -0.019654         -0.048864         -0.033259
# area_cluster_C9             -0.007655         -0.019032         -0.012954
#
#                      area_cluster_C3  area_cluster_C4  area_cluster_C5  \
# policy_tenure              -0.108658        -0.011767        -0.073060
# age_of_car                 -0.139679        -0.033640        -0.064938
# age_of_policyholder        -0.032487        -0.021473         0.022337
# population_density         -0.287721         0.024880         0.342090
# make                       -0.072711        -0.016599        -0.055709
# ...                              ...              ...              ...
# area_cluster_C5            -0.121644        -0.041540         1.000000
# area_cluster_C6            -0.047667        -0.016278        -0.047624
# area_cluster_C7            -0.068216        -0.023295        -0.068155
# area_cluster_C8            -0.197044        -0.067288        -0.196868
# area_cluster_C9            -0.076748        -0.026208        -0.076679
#
#                      area_cluster_C6  area_cluster_C7  area_cluster_C8  \
# policy_tenure              -0.002231        -0.043203         0.184921
# age_of_car                 -0.017511        -0.025076         0.189789
# age_of_policyholder        -0.020159        -0.070694         0.040219
# population_density         -0.040435        -0.137762        -0.308732
# make                        0.002792        -0.009593         0.101943
# ...                              ...              ...              ...
# area_cluster_C5            -0.047624        -0.068155        -0.196868
# area_cluster_C6             1.000000        -0.026707        -0.077144
# area_cluster_C7            -0.026707         1.000000        -0.110400
# area_cluster_C8            -0.077144        -0.110400         1.000000
# area_cluster_C9            -0.030047        -0.043000        -0.124208
#
#                      area_cluster_C9
# policy_tenure              -0.078068
# age_of_car                 -0.015817
# age_of_policyholder         0.021410
# population_density         -0.003533
# make                       -0.011172
# ...                              ...
# area_cluster_C5            -0.076679
# area_cluster_C6            -0.030047
# area_cluster_C7            -0.043000
# area_cluster_C8            -0.124208
# area_cluster_C9             1.000000
#
# [99 rows x 99 columns]

# %%
# x = df.columns
# from sklearn.preprocessing import StandardScaler
# model = StandardScaler()
# model.fit(df)
# df_scaled = model.transform(df)
# df = pd.DataFrame(df_scaled,columns=x)
# df

# %%
df.corr()
# Out:
#                      policy_tenure  age_of_car  age_of_policyholder  \
# policy_tenure             1.000000    0.167382             0.151350
# age_of_car                0.167382    1.000000            -0.026895
# age_of_policyholder       0.151350   -0.026895             1.000000
# population_density       -0.092580   -0.070770             0.018235
# make                      0.117186    0.190297            -0.014334
# ...                            ...         ...                  ...
# area_cluster_C5          -0.073060   -0.064938             0.022337
# area_cluster_C6          -0.002231   -0.017511            -0.020159
# area_cluster_C7          -0.043203   -0.025076            -0.070694
# area_cluster_C8           0.184921    0.189789             0.040219
# area_cluster_C9          -0.078068   -0.015817             0.021410
#
#                      population_density      make  is_claim   airbags  \
# policy_tenure                 -0.092580  0.117186  0.140640  0.121549
# age_of_car                    -0.070770  0.190297 -0.069575  0.216567
# age_of_policyholder            0.018235 -0.014334  0.037825  0.005050
# population_density             1.000000 -0.064446 -0.015312 -0.074476
# make                          -0.064446  1.000000  0.003614  0.493488
# ...                                 ...       ...       ...       ...
# area_cluster_C5                0.342090 -0.055709 -0.004633 -0.049442
# area_cluster_C6               -0.040435  0.002792 -0.011814 -0.009121
# area_cluster_C7               -0.137762 -0.009593 -0.027213 -0.019582
# area_cluster_C8               -0.308732  0.101943  0.022118  0.133917
# area_cluster_C9               -0.003533 -0.011172 -0.027909 -0.013784
#
#                        is_esc  is_adjustable_steering   is_tpms  ...  \
# policy_tenure        0.123202                0.213590  0.106461  ...
# age_of_car           0.230468                0.394027  0.208524  ...
# age_of_policyholder -0.002672                0.021964  0.014514  ...
# population_density  -0.066545               -0.098360 -0.077934  ...
# make                 0.471191                0.426663  0.607821  ...
# ...                       ...                     ...       ...  ...
# area_cluster_C5     -0.046047               -0.104193 -0.052712  ...
# area_cluster_C6     -0.016297               -0.027681 -0.008218  ...
# area_cluster_C7     -0.027798               -0.036817 -0.010040  ...
# area_cluster_C8      0.133958                0.245268  0.140430  ...
# area_cluster_C9     -0.012006               -0.038700 -0.023784  ...
#
#                      area_cluster_C20  area_cluster_C21  area_cluster_C22  \
# policy_tenure               -0.034675         -0.003539          0.000526
# age_of_car                   0.000298         -0.001733          0.000957
# age_of_policyholder         -0.024838         -0.006227         -0.008565
# population_density           0.005797         -0.075489         -0.004661
# make                        -0.014275         -0.012910         -0.010419
# ...                               ...               ...               ...
# area_cluster_C5             -0.012133         -0.030166         -0.020532
# area_cluster_C6             -0.004754         -0.011821         -0.008046
# area_cluster_C7             -0.006804         -0.016916         -0.011514
# area_cluster_C8             -0.019654         -0.048864         -0.033259
# area_cluster_C9             -0.007655         -0.019032         -0.012954
#
#                      area_cluster_C3  area_cluster_C4  area_cluster_C5  \
# policy_tenure              -0.108658        -0.011767        -0.073060
# age_of_car                 -0.139679        -0.033640        -0.064938
# age_of_policyholder        -0.032487        -0.021473         0.022337
# population_density         -0.287721         0.024880         0.342090
# make                       -0.072711        -0.016599        -0.055709
# ...                              ...              ...              ...
# area_cluster_C5            -0.121644        -0.041540         1.000000
# area_cluster_C6            -0.047667        -0.016278        -0.047624
# area_cluster_C7            -0.068216        -0.023295        -0.068155
# area_cluster_C8            -0.197044        -0.067288        -0.196868
# area_cluster_C9            -0.076748        -0.026208        -0.076679
#
#                      area_cluster_C6  area_cluster_C7  area_cluster_C8  \
# policy_tenure              -0.002231        -0.043203         0.184921
# age_of_car                 -0.017511        -0.025076         0.189789
# age_of_policyholder        -0.020159        -0.070694         0.040219
# population_density         -0.040435        -0.137762        -0.308732
# make                        0.002792        -0.009593         0.101943
# ...                              ...              ...              ...
# area_cluster_C5            -0.047624        -0.068155        -0.196868
# area_cluster_C6             1.000000        -0.026707        -0.077144
# area_cluster_C7            -0.026707         1.000000        -0.110400
# area_cluster_C8            -0.077144        -0.110400         1.000000
# area_cluster_C9            -0.030047        -0.043000        -0.124208
#
#                      area_cluster_C9
# policy_tenure              -0.078068
# age_of_car                 -0.015817
# age_of_policyholder         0.021410
# population_density         -0.003533
# make                       -0.011172
# ...                              ...
# area_cluster_C5            -0.076679
# area_cluster_C6            -0.030047
# area_cluster_C7            -0.043000
# area_cluster_C8            -0.124208
# area_cluster_C9             1.000000
#
# [99 rows x 99 columns]

# %%
df.isna().sum()
# Out:
# policy_tenure          0
# age_of_car             0
# age_of_policyholder    0
# population_density     0
# make                   0
#                       ..
# area_cluster_C5        0
# area_cluster_C6        0
# area_cluster_C7        0
# area_cluster_C8        0
# area_cluster_C9        0
# Length: 99, dtype: int64

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
# from sklearn.utils import resample
# # Separate the majority and minority classes
# majority_class = df[df['is_claim'] == 0]
# minority_class = df[df['is_claim'] == 1]

# # Undersample the majority class
# undersampled_majority = resample(
#     majority_class,
#     replace=False,  # Set to False for undersampling
#     n_samples=len(minority_class) * 2,  # Desired number of records in the majority class
#     random_state=42  # Set a random seed for reproducibility
# )

# # Combine the undersampled majority class with the minority class
# df = pd.concat([undersampled_majority, minority_class])

# %%
df.columns
# Out:
# Index(['policy_tenure', 'age_of_car', 'age_of_policyholder',
#        'population_density', 'make', 'is_claim', 'airbags', 'is_esc',
#        'is_adjustable_steering', 'is_tpms', 'is_parking_sensors',
#        'is_parking_camera', 'displacement', 'cylinder', 'gear_box',
#        'turning_radius', 'Length', 'width', 'height', 'Gross_weight',
#        'is_front_fog_lights', 'is_rear_window_wiper', 'is_rear_window_washer',
#        'is_rear_window_defogger', 'is_brake_assist', 'is_power_door_locks',
#        'is_central_locking', 'is_power_steering',
#        'is_driver_seat_height_adjustable', 'is_day_night_rear_view_mirror',
#        'is_ecw', 'is_speed_alert', 'ncap_rating', 'torque', 'rpm',
#        'torque to rpm ratio', 'power', 'rpm1', 'power to rpm ratio',
#        'fuel_type_CNG', 'fuel_type_Diesel', 'fuel_type_Petrol', 'model_M1',
#        'model_M10', 'model_M11', 'model_M2', 'model_M3', 'model_M4',
#        'model_M5', 'model_M6', 'model_M7', 'model_M8', 'model_M9',
#        'rear_brakes_type_Disc', 'rear_brakes_type_Drum',
#        'transmission_type_Automatic', 'transmission_type_Manual',
#        'steering_type_Electric', 'steering_type_Manual', 'steering_type_Power',
#        'segment_A', 'segment_B1', 'segment_B2', 'segment_C1', 'segment_C2',
#        'segment_Utility', 'engine_type_1.0 SCe',
#        'engine_type_1.2 L K Series Engine', 'engine_type_1.2 L K12N Dualjet',
#        'engine_type_1.5 L U2 CRDi', 'engine_type_1.5 Turbocharged Revotorq',
#        'engine_type_1.5 Turbocharged Revotron',
#        'engine_type_F8D Petrol Engine', 'engine_type_G12B',
#        'engine_type_K Series Dual jet', 'engine_type_K10C',
#        'engine_type_i-DTEC', 'area_cluster_C1', 'area_cluster_C10',
#        'area_cluster_C11', 'area_cluster_C12', 'area_cluster_C13',
#        'area_cluster_C14', 'area_cluster_C15', 'area_cluster_C16',
#        'area_cluster_C17', 'area_cluster_C18', 'area_cluster_C19',
#        'area_cluster_C2', 'area_cluster_C20', 'area_cluster_C21',
#        'area_cluster_C22', 'area_cluster_C3', 'area_cluster_C4',
#        'area_cluster_C5', 'area_cluster_C6', 'area_cluster_C7',
#        'area_cluster_C8', 'area_cluster_C9'],
#       dtype='object')

# %%
x = df.drop(['model_M1',
       'model_M10', 'model_M11', 'model_M2', 'model_M3', 'model_M4',
       'model_M5', 'model_M6', 'model_M7', 'model_M8', 'model_M9',
       'rear_brakes_type_Disc', 'rear_brakes_type_Drum',
       'transmission_type_Automatic', 'transmission_type_Manual',
       'steering_type_Electric', 'steering_type_Manual', 'steering_type_Power',
       'segment_A', 'segment_B1', 'segment_B2', 'segment_C1', 'segment_C2',
       'segment_Utility', 'engine_type_1.0 SCe',
       'engine_type_1.2 L K Series Engine', 'engine_type_1.2 L K12N Dualjet',
       'engine_type_1.5 L U2 CRDi', 'engine_type_1.5 Turbocharged Revotorq',
       'engine_type_1.5 Turbocharged Revotron',
       'engine_type_F8D Petrol Engine', 'engine_type_G12B',
       'engine_type_K Series Dual jet', 'engine_type_K10C',
       'engine_type_i-DTEC', 'area_cluster_C1', 'area_cluster_C10',
       'area_cluster_C11', 'area_cluster_C12', 'area_cluster_C13',
       'area_cluster_C14', 'area_cluster_C15', 'area_cluster_C16',
       'area_cluster_C17', 'area_cluster_C18', 'area_cluster_C19',
       'area_cluster_C2', 'area_cluster_C20', 'area_cluster_C21',
       'area_cluster_C22', 'area_cluster_C3', 'area_cluster_C4',
       'area_cluster_C5', 'area_cluster_C6', 'area_cluster_C7',
       'area_cluster_C8', 'area_cluster_C9','is_claim'],axis=1)
y = df['is_claim']

# %%
df['Length'].value_counts()
# Out:
# Length
# 0    1436
# 4    1424
# 8    1348
# 5     487
# 1     400
# 7     313
# 3     224
# 2     128
# 6      26
# Name: count, dtype: int64

# %%
df['is_claim'].value_counts()
# Out:
# is_claim
# 0    3858
# 1    1928
# Name: count, dtype: int64

# %%
# from imblearn.under_sampling import RandomUnderSampler

# rus = RandomUnderSampler(random_state=21)
# x_resampled, y_resampled = rus.fit_resample(x, y)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,train_size=0.8, random_state=1234567)

# %%
# from imblearn.under_sampling import RandomUnderSampler

# rus = RandomUnderSampler(random_state=21)
# x_resampled, y_resampled = rus.fit_resample(x_train, y_train)

# %%
def build_lg_model():
    from sklearn.linear_model import LogisticRegression

    # create a model
    model = LogisticRegression()

    # train the model
    model.fit(x_train, y_train)

    return model

# %%
def build_knn_model():
    from sklearn.neighbors import KNeighborsClassifier

    # create a model
    model = KNeighborsClassifier(n_neighbors=100)

    # train the model
    model.fit(x_train, y_train)

    return model

# %%
def build_svm_model():
    from sklearn.svm import SVC

    # create a model
    model = SVC()

    # train the model
    model.fit(x_train, y_train)

    return model

# %%
# get lg model
model_lg = build_lg_model()

# get KNN model
model_knn = build_knn_model()

# get SVM model
model_svm = build_svm_model()

# %%
def evaluate_model(model):
    from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score,classification_report
    # define y_true and y_pred
    y_true = y_test
    y_pred = model.predict(x_test)    

    # get confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    print(cm)

    # print accuracy
    # print(f"accuracy = {accuracy_score(y_true, y_pred) * 100:.2f}%")
    # print(f"precision = {precision_score(y_true, y_pred) * 100:.2f}%")
    # print(f"recall = {recall_score(y_true, y_pred) * 100:.2f}%")
    # print(f"F1 score = {f1_score(y_true, y_pred) * 100:.2f}%")
    print(f"C.R = {classification_report(y_true, y_pred)}")

# %%
evaluate_model(model_lg)
# Out:
# [[765   0]
#  [393   0]]
# C.R =               precision    recall  f1-score   support
#
#            0       0.66      1.00      0.80       765
#            1       0.00      0.00      0.00       393
#
#     accuracy                           0.66      1158
#    macro avg       0.33      0.50      0.40      1158
# weighted avg       0.44      0.66      0.53      1158
# /home/sunbeam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sunbeam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sunbeam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
evaluate_model(model_knn)
# Out:
# [[765   0]
#  [393   0]]
# C.R =               precision    recall  f1-score   support
#
#            0       0.66      1.00      0.80       765
#            1       0.00      0.00      0.00       393
#
#     accuracy                           0.66      1158
#    macro avg       0.33      0.50      0.40      1158
# weighted avg       0.44      0.66      0.53      1158
# /home/sunbeam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sunbeam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sunbeam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
evaluate_model(model_svm)
# Out:
# [[765   0]
#  [393   0]]
# C.R =               precision    recall  f1-score   support
#
#            0       0.66      1.00      0.80       765
#            1       0.00      0.00      0.00       393
#
#     accuracy                           0.66      1158
#    macro avg       0.33      0.50      0.40      1158
# weighted avg       0.44      0.66      0.53      1158
# /home/sunbeam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sunbeam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sunbeam/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
