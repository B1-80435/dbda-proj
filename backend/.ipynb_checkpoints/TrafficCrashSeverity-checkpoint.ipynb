# %% [markdown]
# # Project: Traffic Crash Analysis & Forecasting Severity
#
# **Objective:** The objective of this machine learning project is to develop a predictive model that can predict the severity of traffic collisions. The severity levels will be categorized as 0 or 1 based on the collision's impact.
#
# **Tools Used:** Python, Pandas, Matplotlib, Seaborn, NumPy.
#
# **Skills Demonstrated:** Data Cleaning, Exploratory Data Analysis, Forecasting, Data Visualization, Classification, etc.
#
# **Data Source:** https://catalog.data.gov/dataset/traffic-crashes-resulting-in-injury
#
# The dataset contains a wide range of attributes related to traffic collisions in San Francisco, including geographic information, date and time of the collisions, weather conditions, road conditions, lighting, and more.

# %% [markdown]
# ### Problem Definition:
# -  This project aims to address the following key questions:
#     - Can we accurately predict the severity of a traffic collision based on various attributes related to the collision?
#     - What factors contribute to the severity of traffic accidents in San Francisco?
# -  Specifically, the problem involves:
#     - Classification: Developing a machine learning model to predict the collision severity category (Minor, Moderate, Severe) based on input features.
#     - Feature importance: Identifying which attributes have the most significant influence on collision severity.
# - The target variable for classification is "collision_severity."

# %% [markdown]
# ### Importing the required packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# Ignore all warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading The Data

# %%
df = pd.read_csv('Traffic_Crashes_Resulting_in_Injury.csv', low_memory=False)
df.head()
# Out:
#    unique_id  cnn_intrsctn_fkey  cnn_sgmt_fkey case_id_pkey  tb_latitude  \
# 0      15414           23926000            NaN    151003670    37.777857
# 1      52640           23969000            NaN    200212108    37.754453
# 2      36577           22495000      5408000.0    140836694    37.714040
# 3      27582           24726000      9299000.0    160732947    37.791627
# 4      14911           23811000       179000.0    180566685    37.779856
#
#    tb_longitude   geocode_source geocode_location      collision_datetime  \
# 0   -122.406436  SFPD-CROSSROADS      CITY STREET  11/18/2015 09:04:00 AM
# 1   -122.408343  SFPD-INTERIM DB      CITY STREET  03/28/2020 02:35:00 PM
# 2   -122.461135  SFPD-CROSSROADS      CITY STREET  10/04/2014 01:25:00 PM
# 3   -122.402516  SFPD-CROSSROADS      CITY STREET  09/08/2016 02:00:00 PM
# 4   -122.394008  SFPD-INTERIM DB      CITY STREET  07/30/2018 11:25:00 AM
#
#       collision_date  ...  party2_move_pre_acc                          point  \
# 0   2015 November 18  ...  Proceeding Straight   POINT (-122.40643 37.777855)
# 1      2020 March 28  ...  Proceeding Straight    POINT (-122.40834 37.75445)
# 2    2014 October 04  ...  Proceeding Straight   POINT (-122.461136 37.71404)
# 3  2016 September 08  ...           Not Stated   POINT (-122.40252 37.791626)
# 4       2018 July 30  ...                  NaN  POINT (-122.394005 37.779858)
#
#                data_as_of         data_updated_at          data_loaded_at  \
# 0  11/18/2015 12:00:00 AM  04/26/2023 12:00:00 AM  09/30/2023 03:30:17 AM
# 1  04/02/2020 12:00:00 AM  04/26/2023 12:00:00 AM  09/30/2023 03:30:23 AM
# 2  10/04/2014 12:00:00 AM  04/26/2023 12:00:00 AM  09/30/2023 03:30:23 AM
# 3  09/08/2016 12:00:00 AM  04/26/2023 12:00:00 AM  09/30/2023 03:30:23 AM
# 4  10/22/2018 12:00:00 AM  04/26/2023 12:00:00 AM  09/30/2023 03:30:25 AM
#
#   Neighborhoods SF Find Neighborhoods Current Police Districts  \
# 0          32.0                  32.0                      1.0
# 1          53.0                  53.0                      3.0
# 2          81.0                  81.0                     10.0
# 3         108.0                 108.0                      6.0
# 4          31.0                  31.0                      1.0
#
#   Current Supervisor Districts Analysis Neighborhoods
# 0                         10.0                   34.0
# 1                          2.0                   20.0
# 2                          1.0                   24.0
# 3                          3.0                    8.0
# 4                         10.0                    8.0
#
# [5 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56009 entries, 0 to 56008
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   unique_id                     56009 non-null  int64
#  1   cnn_intrsctn_fkey             56009 non-null  int64
#  2   cnn_sgmt_fkey                 25199 non-null  float64
#  3   case_id_pkey                  56009 non-null  object
#  4   tb_latitude                   55862 non-null  float64
#  5   tb_longitude                  55862 non-null  float64
#  6   geocode_source                56009 non-null  object
#  7   geocode_location              56009 non-null  object
#  8   collision_datetime            56009 non-null  object
#  9   collision_date                56009 non-null  object
#  10  collision_time                55953 non-null  object
#  11  accident_year                 56009 non-null  int64
#  12  month                         56009 non-null  object
#  13  day_of_week                   56001 non-null  object
#  14  time_cat                      55958 non-null  object
#  15  juris                         56009 non-null  object
#  16  officer_id                    54945 non-null  object
#  17  reporting_district            49499 non-null  object
#  18  beat_number                   51640 non-null  object
#  19  primary_rd                    56009 non-null  object
#  20  secondary_rd                  55917 non-null  object
#  21  distance                      55930 non-null  float64
#  22  direction                     56008 non-null  object
#  23  weather_1                     56009 non-null  object
#  24  weather_2                     55213 non-null  object
#  25  collision_severity            56009 non-null  object
#  26  type_of_collision             56009 non-null  object
#  27  mviw                          56009 non-null  object
#  28  ped_action                    56009 non-null  object
#  29  road_surface                  56009 non-null  object
#  30  road_cond_1                   56009 non-null  object
#  31  road_cond_2                   56009 non-null  object
#  32  lighting                      56009 non-null  object
#  33  control_device                37145 non-null  object
#  34  intersection                  56008 non-null  object
#  35  vz_pcf_code                   56008 non-null  object
#  36  vz_pcf_group                  55201 non-null  object
#  37  vz_pcf_description            56009 non-null  object
#  38  vz_pcf_link                   55331 non-null  object
#  39  number_killed                 56006 non-null  float64
#  40  number_injured                56009 non-null  int64
#  41  street_view                   55883 non-null  object
#  42  dph_col_grp                   56009 non-null  object
#  43  dph_col_grp_description       56009 non-null  object
#  44  party_at_fault                50463 non-null  float64
#  45  party1_type                   55998 non-null  object
#  46  party1_dir_of_travel          55998 non-null  object
#  47  party1_move_pre_acc           55999 non-null  object
#  48  party2_type                   52027 non-null  object
#  49  party2_dir_of_travel          52029 non-null  object
#  50  party2_move_pre_acc           52030 non-null  object
#  51  point                         55862 non-null  object
#  52  data_as_of                    56009 non-null  object
#  53  data_updated_at               56009 non-null  object
#  54  data_loaded_at                56009 non-null  object
#  55  Neighborhoods                 55236 non-null  float64
#  56  SF Find Neighborhoods         55236 non-null  float64
#  57  Current Police Districts      55778 non-null  float64
#  58  Current Supervisor Districts  55817 non-null  float64
#  59  Analysis Neighborhoods        55804 non-null  float64
# dtypes: float64(11), int64(4), object(45)
# memory usage: 25.6+ MB

# %%
df.describe()
# Out:
#           unique_id  cnn_intrsctn_fkey  cnn_sgmt_fkey   tb_latitude  \
# count  56009.000000       5.600900e+04   2.519900e+04  55862.000000
# mean   29632.929654       2.587432e+07   6.971339e+06     37.765905
# std    17521.588792       4.920412e+06   4.075008e+06      0.024434
# min        1.000000       2.000600e+07   1.000000e+05     37.707459
# 25%    14613.000000       2.387100e+07   3.454500e+06     37.749041
# 50%    29148.000000       2.493600e+07   7.311000e+06     37.772569
# 75%    43664.000000       2.670400e+07   1.014700e+07     37.783933
# max    61487.000000       5.436600e+07   1.999910e+07     37.829991
#
#        tb_longitude  accident_year      distance  number_killed  \
# count  55862.000000   56009.000000  55930.000000   56006.000000
# mean    -122.428868    2013.565213     56.946826       0.009588
# std        0.028407       5.196015    273.890229       0.099624
# min     -122.513616    2005.000000      0.000000       0.000000
# 25%     -122.443431    2009.000000      0.000000       0.000000
# 50%     -122.421578    2014.000000      0.000000       0.000000
# 75%     -122.408490    2018.000000     52.000000       0.000000
# max     -122.358328    2023.000000  26400.000000       3.000000
#
#        number_injured  party_at_fault  Neighborhoods  SF Find Neighborhoods  \
# count    56009.000000    50463.000000   55236.000000           55236.000000
# mean         1.257994        1.013495      53.745474              53.745474
# std          0.703334        0.126210      32.679027              32.679027
# min          0.000000        1.000000       1.000000               1.000000
# 25%          1.000000        1.000000      28.000000              28.000000
# 50%          1.000000        1.000000      50.000000              50.000000
# 75%          1.000000        1.000000      86.000000              86.000000
# max         19.000000        5.000000     117.000000             117.000000
#
#        Current Police Districts  Current Supervisor Districts  \
# count              55778.000000                  55817.000000
# mean                   5.163129                      6.619238
# std                    2.979027                      3.375530
# min                    1.000000                      1.000000
# 25%                    3.000000                      3.000000
# 50%                    4.000000                      7.000000
# 75%                    8.000000                     10.000000
# max                   10.000000                     11.000000
#
#        Analysis Neighborhoods
# count            55804.000000
# mean                20.693803
# std                 12.332206
# min                  1.000000
# 25%                  9.000000
# 50%                 20.000000
# 75%                 34.000000
# max                 41.000000

# %%
df.isnull().sum()
# Out:
# unique_id                           0
# cnn_intrsctn_fkey                   0
# cnn_sgmt_fkey                   30810
# case_id_pkey                        0
# tb_latitude                       147
# tb_longitude                      147
# geocode_source                      0
# geocode_location                    0
# collision_datetime                  0
# collision_date                      0
# collision_time                     56
# accident_year                       0
# month                               0
# day_of_week                         8
# time_cat                           51
# juris                               0
# officer_id                       1064
# reporting_district               6510
# beat_number                      4369
# primary_rd                          0
# secondary_rd                       92
# distance                           79
# direction                           1
# weather_1                           0
# weather_2                         796
# collision_severity                  0
# type_of_collision                   0
# mviw                                0
# ped_action                          0
# road_surface                        0
# road_cond_1                         0
# road_cond_2                         0
# lighting                            0
# control_device                  18864
# intersection                        1
# vz_pcf_code                         1
# vz_pcf_group                      808
# vz_pcf_description                  0
# vz_pcf_link                       678
# number_killed                       3
# number_injured                      0
# street_view                       126
# dph_col_grp                         0
# dph_col_grp_description             0
# party_at_fault                   5546
# party1_type                        11
# party1_dir_of_travel               11
# party1_move_pre_acc                10
# party2_type                      3982
# party2_dir_of_travel             3980
# party2_move_pre_acc              3979
# point                             147
# data_as_of                          0
# data_updated_at                     0
# data_loaded_at                      0
# Neighborhoods                     773
# SF Find Neighborhoods             773
# Current Police Districts          231
# Current Supervisor Districts      192
# Analysis Neighborhoods            205
# dtype: int64

# %%
df.shape
# Out:
# (56009, 60)

# %%
df.columns
# Out:
# Index(['unique_id', 'cnn_intrsctn_fkey', 'cnn_sgmt_fkey', 'case_id_pkey',
#        'tb_latitude', 'tb_longitude', 'geocode_source', 'geocode_location',
#        'collision_datetime', 'collision_date', 'collision_time',
#        'accident_year', 'month', 'day_of_week', 'time_cat', 'juris',
#        'officer_id', 'reporting_district', 'beat_number', 'primary_rd',
#        'secondary_rd', 'distance', 'direction', 'weather_1', 'weather_2',
#        'collision_severity', 'type_of_collision', 'mviw', 'ped_action',
#        'road_surface', 'road_cond_1', 'road_cond_2', 'lighting',
#        'control_device', 'intersection', 'vz_pcf_code', 'vz_pcf_group',
#        'vz_pcf_description', 'vz_pcf_link', 'number_killed', 'number_injured',
#        'street_view', 'dph_col_grp', 'dph_col_grp_description',
#        'party_at_fault', 'party1_type', 'party1_dir_of_travel',
#        'party1_move_pre_acc', 'party2_type', 'party2_dir_of_travel',
#        'party2_move_pre_acc', 'point', 'data_as_of', 'data_updated_at',
#        'data_loaded_at', 'Neighborhoods', 'SF Find Neighborhoods',
#        'Current Police Districts', 'Current Supervisor Districts',
#        'Analysis Neighborhoods'],
#       dtype='object')

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
selected_features = ['collision_severity','weather_1', 'road_surface', 'road_cond_1', 'road_cond_2', 'lighting',
                     'type_of_collision', 'party1_type', 'party2_type', 'party1_dir_of_travel', 'party2_dir_of_travel']

# %%
df1 = df[selected_features]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56009 entries, 0 to 56008
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   collision_severity    56009 non-null  object
#  1   weather_1             56009 non-null  object
#  2   road_surface          56009 non-null  object
#  3   road_cond_1           56009 non-null  object
#  4   road_cond_2           56009 non-null  object
#  5   lighting              56009 non-null  object
#  6   type_of_collision     56009 non-null  object
#  7   party1_type           55998 non-null  object
#  8   party2_type           52027 non-null  object
#  9   party1_dir_of_travel  55998 non-null  object
#  10  party2_dir_of_travel  52029 non-null  object
# dtypes: object(11)
# memory usage: 4.7+ MB

# %%
df1.head(5)
# Out:
#            collision_severity   weather_1 road_surface           road_cond_1  \
# 0  Injury (Complaint of Pain)       Clear          Dry  No Unusual Condition
# 1      Injury (Other Visible)      Cloudy          Dry  No Unusual Condition
# 2  Injury (Complaint of Pain)       Clear          Dry  No Unusual Condition
# 3      Injury (Other Visible)  Not Stated   Not Stated            Not Stated
# 4             Injury (Severe)       Clear          Dry      Holes, Deep Ruts
#
#   road_cond_2    lighting   type_of_collision     party1_type party2_type  \
# 0  Not Stated    Daylight               Other          Driver   Bicyclist
# 1  Not Stated    Daylight           Broadside       Bicyclist      Driver
# 2  Not Stated    Daylight  Vehicle/Pedestrian          Driver  Pedestrian
# 3  Not Stated  Not Stated          Not Stated  Parked Vehicle   Bicyclist
# 4  Not Stated    Daylight          Not Stated       Bicyclist         NaN
#
#   party1_dir_of_travel party2_dir_of_travel
# 0                 East                 East
# 1                 East                South
# 2                North                 West
# 3                South                South
# 4                North                  NaN

# %%
df1.isna().sum()
# Out:
# collision_severity         0
# weather_1                  0
# road_surface               0
# road_cond_1                0
# road_cond_2                0
# lighting                   0
# type_of_collision          0
# party1_type               11
# party2_type             3982
# party1_dir_of_travel      11
# party2_dir_of_travel    3980
# dtype: int64

# %%
df['collision_severity'].unique()
# Out:
# array(['Injury (Complaint of Pain)', 'Injury (Other Visible)',
#        'Injury (Severe)', 'Fatal', 'Medical'], dtype=object)

# %% [markdown]
# ### Dropping unneccessary columns

# %%
unselected_features = df.drop(selected_features,axis=1)

# %%
unselected_features.shape
# Out:
# (56009, 49)

# %%
unselected_features.head()
# Out:
#    unique_id  cnn_intrsctn_fkey  cnn_sgmt_fkey case_id_pkey  tb_latitude  \
# 0      15414           23926000            NaN    151003670    37.777857
# 1      52640           23969000            NaN    200212108    37.754453
# 2      36577           22495000      5408000.0    140836694    37.714040
# 3      27582           24726000      9299000.0    160732947    37.791627
# 4      14911           23811000       179000.0    180566685    37.779856
#
#    tb_longitude   geocode_source geocode_location      collision_datetime  \
# 0   -122.406436  SFPD-CROSSROADS      CITY STREET  11/18/2015 09:04:00 AM
# 1   -122.408343  SFPD-INTERIM DB      CITY STREET  03/28/2020 02:35:00 PM
# 2   -122.461135  SFPD-CROSSROADS      CITY STREET  10/04/2014 01:25:00 PM
# 3   -122.402516  SFPD-CROSSROADS      CITY STREET  09/08/2016 02:00:00 PM
# 4   -122.394008  SFPD-INTERIM DB      CITY STREET  07/30/2018 11:25:00 AM
#
#       collision_date  ...  party2_move_pre_acc                          point  \
# 0   2015 November 18  ...  Proceeding Straight   POINT (-122.40643 37.777855)
# 1      2020 March 28  ...  Proceeding Straight    POINT (-122.40834 37.75445)
# 2    2014 October 04  ...  Proceeding Straight   POINT (-122.461136 37.71404)
# 3  2016 September 08  ...           Not Stated   POINT (-122.40252 37.791626)
# 4       2018 July 30  ...                  NaN  POINT (-122.394005 37.779858)
#
#                data_as_of         data_updated_at          data_loaded_at  \
# 0  11/18/2015 12:00:00 AM  04/26/2023 12:00:00 AM  09/30/2023 03:30:17 AM
# 1  04/02/2020 12:00:00 AM  04/26/2023 12:00:00 AM  09/30/2023 03:30:23 AM
# 2  10/04/2014 12:00:00 AM  04/26/2023 12:00:00 AM  09/30/2023 03:30:23 AM
# 3  09/08/2016 12:00:00 AM  04/26/2023 12:00:00 AM  09/30/2023 03:30:23 AM
# 4  10/22/2018 12:00:00 AM  04/26/2023 12:00:00 AM  09/30/2023 03:30:25 AM
#
#   Neighborhoods SF Find Neighborhoods Current Police Districts  \
# 0          32.0                  32.0                      1.0
# 1          53.0                  53.0                      3.0
# 2          81.0                  81.0                     10.0
# 3         108.0                 108.0                      6.0
# 4          31.0                  31.0                      1.0
#
#   Current Supervisor Districts Analysis Neighborhoods
# 0                         10.0                   34.0
# 1                          2.0                   20.0
# 2                          1.0                   24.0
# 3                          3.0                    8.0
# 4                         10.0                    8.0
#
# [5 rows x 49 columns]

# %%
unselected_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56009 entries, 0 to 56008
# Data columns (total 49 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   unique_id                     56009 non-null  int64
#  1   cnn_intrsctn_fkey             56009 non-null  int64
#  2   cnn_sgmt_fkey                 25199 non-null  float64
#  3   case_id_pkey                  56009 non-null  object
#  4   tb_latitude                   55862 non-null  float64
#  5   tb_longitude                  55862 non-null  float64
#  6   geocode_source                56009 non-null  object
#  7   geocode_location              56009 non-null  object
#  8   collision_datetime            56009 non-null  object
#  9   collision_date                56009 non-null  object
#  10  collision_time                55953 non-null  object
#  11  accident_year                 56009 non-null  int64
#  12  month                         56009 non-null  object
#  13  day_of_week                   56001 non-null  object
#  14  time_cat                      55958 non-null  object
#  15  juris                         56009 non-null  object
#  16  officer_id                    54945 non-null  object
#  17  reporting_district            49499 non-null  object
#  18  beat_number                   51640 non-null  object
#  19  primary_rd                    56009 non-null  object
#  20  secondary_rd                  55917 non-null  object
#  21  distance                      55930 non-null  float64
#  22  direction                     56008 non-null  object
#  23  weather_2                     55213 non-null  object
#  24  mviw                          56009 non-null  object
#  25  ped_action                    56009 non-null  object
#  26  control_device                37145 non-null  object
#  27  intersection                  56008 non-null  object
#  28  vz_pcf_code                   56008 non-null  object
#  29  vz_pcf_group                  55201 non-null  object
#  30  vz_pcf_description            56009 non-null  object
#  31  vz_pcf_link                   55331 non-null  object
#  32  number_killed                 56006 non-null  float64
#  33  number_injured                56009 non-null  int64
#  34  street_view                   55883 non-null  object
#  35  dph_col_grp                   56009 non-null  object
#  36  dph_col_grp_description       56009 non-null  object
#  37  party_at_fault                50463 non-null  float64
#  38  party1_move_pre_acc           55999 non-null  object
#  39  party2_move_pre_acc           52030 non-null  object
#  40  point                         55862 non-null  object
#  41  data_as_of                    56009 non-null  object
#  42  data_updated_at               56009 non-null  object
#  43  data_loaded_at                56009 non-null  object
#  44  Neighborhoods                 55236 non-null  float64
#  45  SF Find Neighborhoods         55236 non-null  float64
#  46  Current Police Districts      55778 non-null  float64
#  47  Current Supervisor Districts  55817 non-null  float64
#  48  Analysis Neighborhoods        55804 non-null  float64
# dtypes: float64(11), int64(4), object(34)
# memory usage: 20.9+ MB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56009 entries, 0 to 56008
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   collision_severity    56009 non-null  object
#  1   weather_1             56009 non-null  object
#  2   road_surface          56009 non-null  object
#  3   road_cond_1           56009 non-null  object
#  4   road_cond_2           56009 non-null  object
#  5   lighting              56009 non-null  object
#  6   type_of_collision     56009 non-null  object
#  7   party1_type           55998 non-null  object
#  8   party2_type           52027 non-null  object
#  9   party1_dir_of_travel  55998 non-null  object
#  10  party2_dir_of_travel  52029 non-null  object
# dtypes: object(11)
# memory usage: 4.7+ MB

# %%
df1.columns
# Out:
# Index(['collision_severity', 'weather_1', 'road_surface', 'road_cond_1',
#        'road_cond_2', 'lighting', 'type_of_collision', 'party1_type',
#        'party2_type', 'party1_dir_of_travel', 'party2_dir_of_travel'],
#       dtype='object')

# %%
categorical_columns = ['collision_severity', 'weather_1', 'road_surface', 'road_cond_1',
       'road_cond_2', 'lighting', 'type_of_collision', 'party1_type',
       'party2_type', 'party1_dir_of_travel', 'party2_dir_of_travel']

# %%
df1 = df1.dropna()

# %%
df1.isna().sum()
# Out:
# collision_severity      0
# weather_1               0
# road_surface            0
# road_cond_1             0
# road_cond_2             0
# lighting                0
# type_of_collision       0
# party1_type             0
# party2_type             0
# party1_dir_of_travel    0
# party2_dir_of_travel    0
# dtype: int64

# %%
df1.shape
# Out:
# (52018, 11)

# %% [markdown]
# ### Encoding categorical columns & Getting highest correlation

# %%
from sklearn.preprocessing import LabelEncoder

# List of selected columns
selected_features = ['collision_severity', 'weather_1', 'road_surface', 'road_cond_1',
       'road_cond_2', 'lighting', 'type_of_collision', 'party1_type',
       'party2_type', 'party1_dir_of_travel', 'party2_dir_of_travel']


# Subset the DataFrame with selected columns
df_selected = df1[selected_features]

# List of columns with object dtype (assumed categorical)
categorical_columns = df_selected.select_dtypes(include=['object']).columns.tolist()

# Label encode categorical columns
label_encoder = LabelEncoder()
for col in categorical_columns:
    if col in df_selected.columns:
        df_selected[col] = label_encoder.fit_transform(df_selected[col].astype(str))

# Compute correlation matrix
correlation_matrix = df_selected.corr()

# # Get highest correlated columns with 'collision_severity'
# highest_corr_cols = correlation_matrix.abs().nlargest(10, 'collision_severity')['collision_severity'].index.tolist()

# # Display highest correlated columns
# print("Highest Correlated Columns with 'collision_severity' column:")
# print(highest_corr_cols)
# Out:
# Highest Correlated Columns with 'collision_severity' column:
# ['collision_severity', 'party1_type', 'party2_type', 'lighting', 'road_surface', 'type_of_collision', 'weather_1', 'party1_dir_of_travel', 'road_cond_1', 'party2_dir_of_travel']

# %%
# Compute correlation matrix
correlation_matrix = df_selected.corr()
correlation_matrix
# Out:
#                       collision_severity  weather_1  road_surface  \
# collision_severity              1.000000  -0.026323     -0.027584
# weather_1                      -0.026323   1.000000      0.749048
# road_surface                   -0.027584   0.749048      1.000000
# road_cond_1                     0.006671   0.046504      0.030109
# road_cond_2                     0.001053  -0.005463     -0.008076
# lighting                       -0.032496  -0.115174     -0.126681
# type_of_collision               0.027582   0.051900      0.047174
# party1_type                     0.102174   0.028728      0.023687
# party2_type                     0.040696   0.089439      0.091060
# party1_dir_of_travel            0.006964  -0.001803     -0.002628
# party2_dir_of_travel            0.001134   0.004388     -0.000007
#
#                       road_cond_1  road_cond_2  lighting  type_of_collision  \
# collision_severity       0.006671     0.001053 -0.032496           0.027582
# weather_1                0.046504    -0.005463 -0.115174           0.051900
# road_surface             0.030109    -0.008076 -0.126681           0.047174
# road_cond_1              1.000000    -0.049741  0.033058           0.009571
# road_cond_2             -0.049741     1.000000  0.003148          -0.007278
# lighting                 0.033058     0.003148  1.000000          -0.023315
# type_of_collision        0.009571    -0.007278 -0.023315           1.000000
# party1_type             -0.000166     0.001099 -0.047870           0.270266
# party2_type              0.008701    -0.001391 -0.050712           0.423211
# party1_dir_of_travel    -0.009135     0.002710 -0.014781          -0.003682
# party2_dir_of_travel    -0.004811    -0.001200 -0.028193          -0.012016
#
#                       party1_type  party2_type  party1_dir_of_travel  \
# collision_severity       0.102174     0.040696              0.006964
# weather_1                0.028728     0.089439             -0.001803
# road_surface             0.023687     0.091060             -0.002628
# road_cond_1             -0.000166     0.008701             -0.009135
# road_cond_2              0.001099    -0.001391              0.002710
# lighting                -0.047870    -0.050712             -0.014781
# type_of_collision        0.270266     0.423211             -0.003682
# party1_type              1.000000    -0.130506              0.000970
# party2_type             -0.130506     1.000000              0.021856
# party1_dir_of_travel     0.000970     0.021856              1.000000
# party2_dir_of_travel     0.018353    -0.006373              0.233185
#
#                       party2_dir_of_travel
# collision_severity                0.001134
# weather_1                         0.004388
# road_surface                     -0.000007
# road_cond_1                      -0.004811
# road_cond_2                      -0.001200
# lighting                         -0.028193
# type_of_collision                -0.012016
# party1_type                       0.018353
# party2_type                      -0.006373
# party1_dir_of_travel              0.233185
# party2_dir_of_travel              1.000000

# %%
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %% [markdown]
# ### Checking the Data balance

# %%
df1['collision_severity'].value_counts()
# Out:
# collision_severity
# Injury (Complaint of Pain)    33957
# Injury (Other Visible)        14244
# Injury (Severe)                3365
# Fatal                           452
# Name: count, dtype: int64

# %%
# check the data balance for collision_severity
df1['collision_severity'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='collision_severity'>

# %%
target_variable = 'collision_severity'

severity_distribution = df_selected[target_variable].value_counts()

print(f"Distribution of '{target_variable}' column:")
print(severity_distribution)

# Calculate the imbalance ratio
imbalance_ratio = severity_distribution.min() / severity_distribution.max()

if imbalance_ratio >= 1:  
    print("The data is imbalanced.")
else:
    print("The data is balanced.")
# Out:
# Distribution of 'collision_severity' column:
# collision_severity
# 1    33957
# 2    14244
# 3     3365
# 0      452
# Name: count, dtype: int64
# The data is balanced.

# %%
df_selected
# Out:
#        collision_severity  weather_1  road_surface  road_cond_1  road_cond_2  \
# 0                       1          0             0            5            3
# 1                       2          1             0            5            3
# 2                       1          0             0            5            3
# 3                       2          5             1            6            3
# 6                       1          0             0            5            3
# ...                   ...        ...           ...          ...          ...
# 56004                   1          0             0            5            3
# 56005                   2          0             0            5            3
# 56006                   1          0             0            5            3
# 56007                   2          0             0            5            3
# 56008                   3          0             0            5            3
#
#        lighting  type_of_collision  party1_type  party2_type  \
# 0             3                  4            2            0
# 1             3                  0            1            1
# 2             3                  8            2            5
# 3             5                  3            5            0
# 6             3                  0            2            1
# ...         ...                ...          ...          ...
# 56004         3                  0            2            1
# 56005         3                  6            2            1
# 56006         3                  0            2            1
# 56007         5                  0            2            1
# 56008         1                  0            2            1
#
#        party1_dir_of_travel  party2_dir_of_travel
# 0                         0                     0
# 1                         0                     3
# 2                         1                     4
# 3                         3                     3
# 6                         1                     4
# ...                     ...                   ...
# 56004                     1                     0
# 56005                     3                     3
# 56006                     3                     0
# 56007                     0                     3
# 56008                     4                     4
#
# [52018 rows x 11 columns]

# %%
# Select columns for comparison
selected_columns = ['weather_1', 'road_surface', 'road_cond_1', 'road_cond_2',
                    'lighting', 'type_of_collision', 'party1_type', 'party2_type', 'party1_dir_of_travel',
                    'party2_dir_of_travel', 'collision_severity']

# Subset the DataFrame with selected columns
df_s1 = df1[selected_columns]

# Set up figure and axes for subplots
fig, axs = plt.subplots(nrows=5, ncols=2, figsize=(22, 22))

# Flatten the axes for easy iteration
axs = axs.flatten()

# Plot each column against 'collision_severity'
for i, column in enumerate(df_s1.columns[:-1]):  # Exclude 'collision_severity'
    sns.countplot(x=column, hue='collision_severity', data=df_s1, ax=axs[i])
    axs[i].set_title(f'{column} vs Collision Severity')
    axs[i].legend(title='Collision Severity')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Data Preprocessing

# %%
# split the data in X and Y
X = df_selected[['weather_1', 'road_surface', 'road_cond_1', 'road_cond_2',
                 'lighting', 'type_of_collision', 'party1_type', 'party2_type', 'party1_dir_of_travel',
                 'party2_dir_of_travel']]
Y = df_selected['collision_severity']

# %%
from sklearn.model_selection import train_test_split

# Splitting data maintaining class balance with stratification
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.7, stratify=Y, random_state=12345)

# %%
# Handle unknown labels
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %% [markdown]
# #### Model building

# %% [markdown]
# #### save the model

# %%
import pickle

def save_model(model, name):
    with open(name, 'wb') as file:
        pickle.dump(model, file)

# %%
def build_svm_model():
    from sklearn.svm import SVC
    model = SVC(C=2, kernel='rbf')
    model.fit(x_train, y_train)
    save_model(model, 'svm.pkl')
    return model

# %%
def build_knn_model():
    from sklearn.neighbors import KNeighborsClassifier
    model = KNeighborsClassifier(n_neighbors=7)
    model.fit(x_train, y_train)
    save_model(model, 'knn.pkl')
    return model

# %%
def build_nb_model():
    from sklearn.naive_bayes import GaussianNB
    model = GaussianNB()
    model.fit(x_train, y_train)
    save_model(model, 'nb.pkl')
    return model

# %%
def build_dt_model():
    from sklearn.tree import DecisionTreeClassifier
    model = DecisionTreeClassifier(max_depth=500)
    model.fit(x_train, y_train)
    save_model(model, 'dt.pkl')
    return model

# %%
def build_rf_model():
    from sklearn.ensemble import RandomForestClassifier
    model = RandomForestClassifier(n_estimators=500)
    model.fit(x_train, y_train)
    save_model(model, 'rf.pkl')
    return model

# %%
def build_catboost_model():
    from catboost import CatBoostClassifier
    model = CatBoostClassifier(verbose=False)
    model.fit(x_train, y_train)
    save_model(model, 'cb.pkl')
    return model

# %%
def build_xgb_model():
    from xgboost import XGBClassifier
    model = XGBClassifier()
    model.fit(x_train, y_train)
    save_model(model, 'xgb.pkl')
    return model

# %%
def build_lg_model():
    from sklearn.linear_model import LogisticRegressionCV
    model = LogisticRegressionCV()
    model.fit(x_train, y_train)
    save_model(model, 'lg.pkl')
    return model

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate_model(model):
    # define y_true and y_pred
    y_true = y_test
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average = 'micro')
    recall = recall_score(y_true, y_pred, average = 'micro')
    f1 = f1_score(y_true, y_pred, average = 'micro')
    return accuracy, precision, recall, f1

# %%
model_metrics = []
model_functions = [
    {"name": "SVM", "function": build_svm_model},
    {"name": "LG", "function": build_lg_model},
    {"name": "KNN", "function": build_knn_model},
    {"name": "NB", "function": build_nb_model},
    {"name": "DT", "function": build_dt_model},
    {"name": "RF", "function": build_rf_model},
    {"name": "CatBoost", "function": build_catboost_model},
    {"name": "XGBoost", "function": build_xgb_model}
]

for model_info in model_functions:
    model = model_info['function']()
    accuracy, precision, recall, f1 = evaluate_model(model)
    model_metrics.append({
        "name": model_info['name'], 
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1": f1
    })

for info in model_metrics:
    print(f"{info['name']:<10}| {info['accuracy']:^5} | {info['precision']:^5} | {info['recall']:^5} | {info['f1']:^5} ")
# Out:
# SVM       | 0.6526336024605921 | 0.6526336024605921 | 0.6526336024605921 | 0.6526336024605921
# LG        | 0.6527617582980905 | 0.6527617582980905 | 0.6527617582980905 | 0.6527617582980905
# KNN       | 0.6341150839420736 | 0.6341150839420736 | 0.6341150839420736 | 0.6341150839420736
# NB        | 0.6379597590670255 | 0.6379597590670255 | 0.6379597590670255 | 0.6379597590670255
# DT        | 0.6315519671921056 | 0.6315519671921056 | 0.6315519671921056 | 0.6315519671921056
# RF        | 0.6369985902857875 | 0.6369985902857875 | 0.6369985902857875 | 0.6369985902857875
# CatBoost  | 0.649365628604383 | 0.649365628604383 | 0.649365628604383 | 0.649365628604383
# XGBoost   | 0.6501986415481226 | 0.6501986415481226 | 0.6501986415481226 | 0.6501986415481226
